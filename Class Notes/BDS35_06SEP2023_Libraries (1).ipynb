# %% [markdown]
# #**Wednesday Sept 06, 2023**

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_chipotle = pd.read_csv(url, sep='\t')
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle[df_chipotle.item_name == 'Chips and Fresh Tomato Salsa']
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %%
df_chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
for value in df_chipotle.item_price:
  print(value[1:-1])

prices = [float(value[1:-1]) for value in df_chipotle.item_price]

df_chipotle.item_price = prices
# Out:
# 2.39
# 3.39
# 3.39
# 2.39
# 16.98
# 10.98
# 1.69
# 11.75
# 9.25
# 9.25
# 4.45
# 8.75
# 8.75
# 11.25
# 4.45
# 2.39
# 8.49
# 8.49
# 2.18
# 8.75
# 4.45
# 8.99
# 3.39
# 10.98
# 3.39
# 2.39
# 8.49
# 8.99
# 1.09
# 8.49
# 2.39
# 8.99
# 1.69
# 8.99
# 1.09
# 8.75
# 8.75
# 4.45
# 2.95
# 11.75
# 2.15
# 4.45
# 11.25
# 11.75
# 8.75
# 10.98
# 8.99
# 3.39
# 8.99
# 3.99
# 8.99
# 2.18
# 10.98
# 1.09
# 8.99
# 2.39
# 9.25
# 11.25
# 11.75
# 2.15
# 4.45
# 9.25
# 11.25
# 8.75
# 8.99
# 8.99
# 3.39
# 8.99
# 10.98
# 8.99
# 1.69
# 8.99
# 3.99
# 8.75
# 4.45
# 8.75
# 8.75
# 2.15
# 8.75
# 11.25
# 2.15
# 9.25
# 8.75
# 8.75
# 9.25
# 8.49
# 8.99
# 1.09
# 9.25
# 2.95
# 11.75
# 11.75
# 9.25
# 11.75
# 4.45
# 9.25
# 4.45
# 11.75
# 8.75
# 8.75
# 4.45
# 8.99
# 8.99
# 3.99
# 8.49
# 3.39
# 8.99
# 1.09
# 9.25
# 4.45
# 8.75
# 2.95
# 4.45
# 2.39
# 8.49
# 8.99
# 8.49
# 1.09
# 8.99
# 3.99
# 8.75
# 9.25
# 4.45
# 11.25
# 4.45
# 8.99
# 1.09
# 9.25
# 2.95
# 4.45
# 11.75
# 4.45
# 8.49
# 2.39
# 10.98
# 22.50
# 11.75
# 4.45
# 11.25
# ...

# %%
#df_chipotle[df_chipotle.choice_description	 == 'Rice']


# Assuming you've already loaded the DataFrame df_chipotle as you mentioned
# Now, filter the DataFrame to select rows where the choice description contains 'Rice'
df_chipotle[df_chipotle['choice_description'].str.contains('Rice')]

# Display the filtered DataFrame
#print(rice_items)

# %%
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_chipotle[df_chipotle.item_price > 10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
df_chipotle.filter(like='item', axis=1)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
df_chipotle.filter(regex='e$', axis=1)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
df_chipotle.filter(items=['choice_description', 'quantity'])
# Out:
#                                      choice_description  quantity
# 0                                                   NaN         1
# 1                                          [Clementine]         1
# 2                                               [Apple]         1
# 3                                                   NaN         1
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...         2
# ...                                                 ...       ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...         1
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...         1
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         1
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...         1
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         1
#
# [4622 rows x 2 columns]

# %%
df_chipotle[df_chipotle.choice_description.isin(['[Clementine]'])]
# Out:
#       order_id  quantity item_name choice_description  item_price
# 1            1         1      Izze       [Clementine]        3.39
# 579        237         1      Izze       [Clementine]        3.39
# 1059       436         1      Izze       [Clementine]        3.39
# 1213       495         1      Izze       [Clementine]        3.39
# 1680       680         1      Izze       [Clementine]        3.39
# 2088       842         1      Izze       [Clementine]        3.39
# 2619      1040         1      Izze       [Clementine]        3.39
# 2634      1046         1      Izze       [Clementine]        3.39

# %%
df_chipotle[df_chipotle.choice_description.str.contains('Clementine')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-4b4c783ad4c1> in <cell line: 1>()
# ----> 1 df_chipotle[df_chipotle.choice_description.str.contains('Clementine')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
# -> 3797         if com.is_bool_indexer(key):
#    3798             return self._getitem_bool_array(key)
#    3799
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
#
# ...

# %%
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df_users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
df_users.occupation.unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
df_users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
df_users.groupby('occupation').sum()
# Out:
# <ipython-input-30-ae37452f49f5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby('occupation').sum()
#                user_id   age
# occupation
# administrator    34045  3061
# artist           12653   879
# doctor            3736   305
# educator         44356  3991
# engineer         30574  2438
# entertainment     7164   526
# executive        13514  1239
# healthcare        8023   665
# homemaker         3101   228
# lawyer            4309   441
# librarian        24816  2040
# marketing        11383   978
# none              3318   239
# other            56987  3625
# programmer       28745  2186
# retired           7220   883
# salesman          5939   428
# scientist        14419  1102
# student          95051  4328
# technician       13436   895
# ...

# %%
df_users.groupby('occupation').min()
# Out:
#                user_id  age gender zip_code
# occupation
# administrator        7   21      F    02154
# artist              23   19      F    01945
# doctor             138   28      M    47401
# educator            13   23      F    01602
# engineer            25   22      F    00000
# entertainment       16   15      F    01040
# executive            6   22      F    00000
# healthcare          60   22      F    02154
# homemaker           20   20      F    17331
# lawyer              10   21      F    06371
# librarian           19   23      F    01080
# marketing           46   24      F    01913
# none                57   11      F    21206
# other                2   13      F    02110
# programmer          17   20      F    01331
# retired            106   51      F    02903
# salesman           112   18      F    30011
# scientist           14   23      F    02113
# student              9    7      F    01002
# technician           1   21      F    02139
# ...

# %%
df_users.groupby('age').min()
# Out:
#      user_id gender     occupation zip_code
# age
# 7         30      M        student    55436
# 10       471      M        student    77459
# 11       289      M           none    94619
# 13       142      F           none    48118
# 14       206      F        student    02136
# ..       ...    ...            ...      ...
# 66       211      M       salesman    32605
# 68       349      M        retired    48911
# 69       559      M      executive    10022
# 70       767      F  administrator    00000
# 73       481      M        retired    37771
#
# [61 rows x 4 columns]

# %%
df_users.groupby('age').mean()
# Out:
# <ipython-input-35-8cca67b0a7e1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby('age').mean()
#         user_id
# age
# 7     30.000000
# 10   471.000000
# 11   289.000000
# 13   586.600000
# 14   635.333333
# ..          ...
# 66   211.000000
# 68   461.000000
# 69   572.000000
# 70   810.000000
# 73   481.000000
#
# [61 rows x 1 columns]

# %%
df_users.count()
# Out:
# user_id       943
# age           943
# gender        943
# occupation    943
# zip_code      943
# dtype: int64

# %%
# df_users.groupby(['gender'== 'M', 'occupation'])['occupation'].count()
#male_users = df_users[df_users['gender'] == 'M']
df_users[(df_users['gender'] == 'M') & (df_users['occupation'] == 'doctor')].groupby('occupation')['occupation'].count()
# Out:
# occupation
# doctor    7
# Name: occupation, dtype: int64

# %%
df_users[(df_users['gender'] == 'F') & (df_users['occupation'] == 'artist')].groupby('occupation')['occupation'].count()
# Out:
# occupation
# artist    13
# Name: occupation, dtype: int64

# %%
df_users.groupby('gender').sum()
# Out:
# <ipython-input-47-d3a5d955fb9a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby('gender').sum()
#         user_id    age
# gender
# F        131424   9231
# M        313672  22880

# %%
df_users.groupby('gender').count()
# Out:
#         user_id  age  occupation  zip_code
# gender
# F           273  273         273       273
# M           670  670         670       670

# %%
df_users[(df_users['age'] >= 50) & (df_users['age'] <= 60)].std()
# Out:
# <ipython-input-40-82e7e0a7942d>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_users[(df_users['age'] >= 50) & (df_users['age'] <= 60)].std()
# user_id    261.706674
# age          3.266627
# dtype: float64

# %%
df_users['age'].count()
# Out:
# 943

# %%
df_users[(df_users['age'] >= 50) & (df_users['age'] <= 60)].sum()
# Out:
# user_id                                                   47724
# age                                                        5529
# gender        FMMMMFMMMMMMFMMMMMMMFFMMFMFFMMFMMMMMMMMMFMMMFM...
# occupation    otheradministratorlawyermarketinghealthcareedu...
# zip_code      9404391344907030710206472481182290220003781550...
# dtype: object
