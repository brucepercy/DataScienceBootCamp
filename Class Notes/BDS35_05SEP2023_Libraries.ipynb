# %% [markdown]
# #**Friday September 01, 2023**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #**Python Pandas DataFrame**

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst1 = [12,23,34,45,56,67,78,89,90,110]
df1 = pd.DataFrame(lst1)
print(df1)
type(df1)
# Out:
#      0
# 0   12
# 1   23
# 2   34
# 3   45
# 4   56
# 5   67
# 6   78
# 7   89
# 8   90
# 9  110
# pandas.core.frame.DataFrame

# %%
lang = ['C','C++','Java','Python']
df2 = pd.DataFrame(lang)
df2
# Out:
#         0
# 0       C
# 1     C++
# 2    Java
# 3  Python

# %%
rating = [4,3,2,1]
df2[1] = rating
df2
# Out:
#         0  1
# 0       C  4
# 1     C++  3
# 2    Java  2
# 3  Python  1

# %%
df2.columns = ['language', 'rating']
df2
# Out:
#   language  rating
# 0        C       4
# 1      C++       3
# 2     Java       2
# 3   Python       1

# %%
# Create Dataframe from Dictionary
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df2 = pd.DataFrame(data)
df3 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b'])
df4 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c'])
df5 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c' , 'd'])

# %%
df2
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
df3
# Out:
#       a   b
# row1  1   2
# row2  5  10

# %%
df4
# Out:
#       a   b     c
# row1  1   2   NaN
# row2  5  10  20.0

# %%
df5
# Out:
#       a   b     c   d
# row1  1   2   NaN NaN
# row2  5  10  20.0 NaN

# %%
df6 = pd.DataFrame({'ID':[1,2,3,4], 'Name':['Ramesh','Suresh','Naresh','Sukesh']})
df6
# Out:
#    ID    Name
# 0   1  Ramesh
# 1   2  Suresh
# 2   3  Naresh
# 3   4  Sukesh

# %%
df6['ID'], df6['Name']
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  Name: ID, dtype: int64,
#  0    Ramesh
#  1    Suresh
#  2    Naresh
#  3    Sukesh
#  Name: Name, dtype: object)

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %% [markdown]
# #**Dataframe of Random Numbers with Date Indices**

# %%
dates = pd.date_range(start='01-Aug-2023', end='31-Aug-2023')

# %%
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('today', periods=7)
dates
# Out:
# DatetimeIndex(['2023-09-06 03:16:59.549807', '2023-09-07 03:16:59.549807',
#                '2023-09-08 03:16:59.549807', '2023-09-09 03:16:59.549807',
#                '2023-09-10 03:16:59.549807', '2023-09-11 03:16:59.549807',
#                '2023-09-12 03:16:59.549807'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('2023-08-25', periods=7)
dates
# Out:
# DatetimeIndex(['2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
M = np.random.random((7,7))
M
# Out:
# array([[0.55290398, 0.68630655, 0.91075408, 0.65588851, 0.35946853,
#         0.86826389, 0.92010742],
#        [0.00560192, 0.96139191, 0.4990781 , 0.2409596 , 0.36156   ,
#         0.71767202, 0.1655317 ],
#        [0.29596867, 0.41368766, 0.61203559, 0.45855985, 0.41434113,
#         0.72009925, 0.33855889],
#        [0.73043767, 0.12586603, 0.59877633, 0.93675756, 0.80751339,
#         0.70497038, 0.16588863],
#        [0.43682906, 0.85989671, 0.41735767, 0.33192487, 0.87966209,
#         0.88761866, 0.54183337],
#        [0.88773161, 0.07577861, 0.66860631, 0.04927479, 0.27359422,
#         0.79683042, 0.77590797],
#        [0.14241722, 0.22093925, 0.77024488, 0.77672245, 0.46728245,
#         0.05547725, 0.59587672]])

# %%
df = pd.DataFrame(M, index=dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                    6
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.columns = ['C1','C2','C3','C4','C5','C6','C7']
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.sort_values(by='C1', ascending=True)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
#
#                   C7
# 2023-08-26  0.165532
# 2023-08-31  0.595877
# 2023-08-27  0.338559
# 2023-08-29  0.541833
# 2023-08-25  0.920107
# 2023-08-28  0.165889
# 2023-08-30  0.775908

# %%
df.sort_values(by='C1', ascending=False)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
#
#                   C7
# 2023-08-30  0.775908
# 2023-08-28  0.165889
# 2023-08-25  0.920107
# 2023-08-29  0.541833
# 2023-08-27  0.338559
# 2023-08-31  0.595877
# 2023-08-26  0.165532

# %%
df.sort_index(ascending=False)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
#
#                   C7
# 2023-08-31  0.595877
# 2023-08-30  0.775908
# 2023-08-29  0.541833
# 2023-08-28  0.165889
# 2023-08-27  0.338559
# 2023-08-26  0.165532
# 2023-08-25  0.920107

# %%
df.loc['2023-08-31']
# Out:
# C1    0.142417
# C2    0.220939
# C3    0.770245
# C4    0.776722
# C5    0.467282
# C6    0.055477
# C7    0.595877
# Name: 2023-08-31 00:00:00, dtype: float64

# %%
df.loc['2023-08-29':'2023-08-31']
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df['C1']
# Out:
# 2023-08-25    0.552904
# 2023-08-26    0.005602
# 2023-08-27    0.295969
# 2023-08-28    0.730438
# 2023-08-29    0.436829
# 2023-08-30    0.887732
# 2023-08-31    0.142417
# Freq: D, Name: C1, dtype: float64

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
del df1['B']
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  4.0
# e  NaN

# %%
dict = {'A' : pd.Series([1, 2, 3,11], index=['a', 'b', 'c','d']),
'B' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df12 = pd.DataFrame(dict)
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis=1, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#    B
# a  1
# b  2
# c  3
# d  4

# %%
df12.drop(['c'], axis=0, inplace=True) # axis=0 => rows,  axis=1 => columns
df12
# Out:
#    B
# a  1
# b  2
# d  4

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10,100,30)
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10
# Out:
#             C1  C2
# 0    10.000000  79
# 1    13.103448  95
# 2    16.206897  23
# 3    19.310345  57
# 4    22.413793  15
# 5    25.517241  77
# 6    28.620690  19
# 7    31.724138  84
# 8    34.827586  56
# 9    37.931034  35
# 10   41.034483  71
# 11   44.137931  71
# 12   47.241379  57
# 13   50.344828  44
# 14   53.448276  19
# 15   56.551724  15
# 16   59.655172  85
# 17   62.758621  82
# 18   65.862069  24
# 19   68.965517  21
# 20   72.068966  92
# 21   75.172414  46
# 22   78.275862  15
# 23   81.379310  77
# 24   84.482759  74
# 25   87.586207  88
# 26   90.689655  94
# 27   93.793103  50
# 28   96.896552  43
# 29  100.000000  64

# %%
df10 = df10.drop([17,18,19], axis=0)
df10
# Out:
#             C1  C2
# 0    10.000000  79
# 1    13.103448  95
# 2    16.206897  23
# 3    19.310345  57
# 4    22.413793  15
# 5    25.517241  77
# 6    28.620690  19
# 7    31.724138  84
# 8    34.827586  56
# 9    37.931034  35
# 10   41.034483  71
# 11   44.137931  71
# 12   47.241379  57
# 13   50.344828  44
# 14   53.448276  19
# 15   56.551724  15
# 16   59.655172  85
# 20   72.068966  92
# 21   75.172414  46
# 22   78.275862  15
# 23   81.379310  77
# 24   84.482759  74
# 25   87.586207  88
# 26   90.689655  94
# 27   93.793103  50
# 28   96.896552  43
# 29  100.000000  64

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  79
# 1    13.103448  95
# 2    16.206897  23
# 3    19.310345  57
# 4    22.413793  15
# 5    25.517241  77
# 6    28.620690  19
# 7    31.724138  84
# 8    34.827586  56
# 9    37.931034  35
# 10   41.034483  71
# 11   44.137931  71
# 12   47.241379  57
# 13   50.344828  44
# 14   53.448276  19
# 15   56.551724  15
# 16   59.655172  85
# 20   72.068966  92
# 21   75.172414  46
# 22   78.275862  15
# 23   81.379310  77
# 24   84.482759  74
# 25   87.586207  88
# 26   90.689655  94
# 27   93.793103  50
# 28   96.896552  43
# 29  100.000000  64

# %%
df10.drop([16], axis=0, inplace=True)
df10
# Out:
#             C1  C2
# 0    10.000000  79
# 1    13.103448  95
# 2    16.206897  23
# 3    19.310345  57
# 4    22.413793  15
# 5    25.517241  77
# 6    28.620690  19
# 7    31.724138  84
# 8    34.827586  56
# 9    37.931034  35
# 10   41.034483  71
# 11   44.137931  71
# 12   47.241379  57
# 13   50.344828  44
# 14   53.448276  19
# 15   56.551724  15
# 20   72.068966  92
# 21   75.172414  46
# 22   78.275862  15
# 23   81.379310  77
# 24   84.482759  74
# 25   87.586207  88
# 26   90.689655  94
# 27   93.793103  50
# 28   96.896552  43
# 29  100.000000  64

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  79
# 1    13.103448  95
# 2    16.206897  23
# 3    19.310345  57
# 4    22.413793  15
# 5    25.517241  77
# 6    28.620690  19
# 7    31.724138  84
# 8    34.827586  56
# 9    37.931034  35
# 10   41.034483  71
# 11   44.137931  71
# 12   47.241379  57
# 13   50.344828  44
# 14   53.448276  19
# 15   56.551724  15
# 20   72.068966  92
# 21   75.172414  46
# 22   78.275862  15
# 23   81.379310  77
# 24   84.482759  74
# 25   87.586207  88
# 26   90.689655  94
# 27   93.793103  50
# 28   96.896552  43
# 29  100.000000  64

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  79
# 1    13.103448  95
# 2    16.206897  23
# 3    19.310345  57
# 4    22.413793  15
# 5    25.517241  77
# 6    28.620690  19
# 7    31.724138  84
# 8    34.827586  56
# 9    37.931034  35
# 10   41.034483  71
# 11   44.137931  71
# 12   47.241379  57
# 13   50.344828  44
# 14   53.448276  19
# 15   56.551724  15
# 20   72.068966  92
# 21   75.172414  46
# 22   78.275862  15
# 23   81.379310  77
# 24   84.482759  74
# 25   87.586207  88
# 26   90.689655  94
# 27   93.793103  50
# 28   96.896552  43
# 29  100.000000  64

# %%
df10.iloc[10:15]
# Out:
#            C1  C2
# 10  41.034483  71
# 11  44.137931  71
# 12  47.241379  57
# 13  50.344828  44
# 14  53.448276  19

# %%
df10.loc[10:15, 'C1']
# Out:
# 10    41.034483
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df10.iloc[10:15, 0]
# Out:
# 10    41.034483
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# Name: C1, dtype: float64

# %%
df10.loc[10:,'C1':]
# Out:
#             C1  C2
# 10   41.034483  71
# 11   44.137931  71
# 12   47.241379  57
# 13   50.344828  44
# 14   53.448276  19
# 15   56.551724  15
# 20   72.068966  92
# 21   75.172414  46
# 22   78.275862  15
# 23   81.379310  77
# 24   84.482759  74
# 25   87.586207  88
# 26   90.689655  94
# 27   93.793103  50
# 28   96.896552  43
# 29  100.000000  64

# %%
df10.iloc[10:, 0:]
# Out:
#             C1  C2
# 10   41.034483  71
# 11   44.137931  71
# 12   47.241379  57
# 13   50.344828  44
# 14   53.448276  19
# 15   56.551724  15
# 20   72.068966  92
# 21   75.172414  46
# 22   78.275862  15
# 23   81.379310  77
# 24   84.482759  74
# 25   87.586207  88
# 26   90.689655  94
# 27   93.793103  50
# 28   96.896552  43
# 29  100.000000  64

# %% [markdown]
# #**Tuesday Sept 01, 2023**

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.loc[:,:] # first parameter is row and then column
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.loc['25-08-2023':'25-08-2023', 'C1':'C1']
# Out:
# <ipython-input-47-6e6e092becc6>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023':'25-08-2023', 'C1':'C1']
#                   C1
# 2023-08-25  0.552904

# %%
df.loc['26-08-2023':'26-08-2023', 'C2':'C2']
# Out:
# <ipython-input-48-ce53f736eb92>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023':'26-08-2023', 'C2':'C2']
#                   C2
# 2023-08-26  0.961392

# %%
df.loc['27-08-2023':'27-08-2023', 'C3':'C3']
# Out:
# <ipython-input-49-06cae008b7ab>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023':'27-08-2023', 'C3':'C3']
#                   C3
# 2023-08-27  0.612036

# %%
df.loc['28-08-2023':'28-08-2023', 'C4':'C4']
# Out:
# <ipython-input-50-12c896dff484>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023':'28-08-2023', 'C4':'C4']
#                   C4
# 2023-08-28  0.936758

# %%
df.loc['29-08-2023':'29-08-2023', 'C5':'C5']
# Out:
# <ipython-input-51-251fc3f450df>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023':'29-08-2023', 'C5':'C5']
#                   C5
# 2023-08-29  0.879662

# %%
df.loc['30-08-2023':'30-08-2023', 'C6':'C6']
# Out:
# <ipython-input-52-87f8056cf8cd>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023':'30-08-2023', 'C6':'C6']
#                  C6
# 2023-08-30  0.79683

# %%
df.loc['31-08-2023':'31-08-2023', 'C7':'C7']
# Out:
# <ipython-input-53-4f649f10f56a>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023':'31-08-2023', 'C7':'C7']
#                   C7
# 2023-08-31  0.595877

# %%
# OPPOSITE

# %%
df.loc['31-08-2023':'31-08-2023', 'C1':'C1']
# Out:
# <ipython-input-55-584ee9bed6e3>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023':'31-08-2023', 'C1':'C1']
#                   C1
# 2023-08-31  0.142417

# %%
df.loc['30-08-2023':'30-08-2023', 'C2':'C2']
# Out:
# <ipython-input-56-472424e4804f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023':'30-08-2023', 'C2':'C2']
#                   C2
# 2023-08-30  0.075779

# %%
df.loc['29-08-2023':'29-08-2023', 'C3':'C3']
# Out:
# <ipython-input-57-bf97756d8ce0>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023':'29-08-2023', 'C3':'C3']
#                   C3
# 2023-08-29  0.417358

# %%
df.loc['28-08-2023':'28-08-2023', 'C7':'C7']
# Out:
# <ipython-input-58-76ad061524b4>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023':'28-08-2023', 'C7':'C7']
#                   C7
# 2023-08-28  0.165889

# %%
df.loc['27-08-2023':'27-08-2023', 'C4':'C4']
# Out:
# <ipython-input-59-6ec42a83e686>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023':'27-08-2023', 'C4':'C4']
#                  C4
# 2023-08-27  0.45856

# %%
df.loc['26-08-2023':'26-08-2023', 'C5':'C5']
# Out:
# <ipython-input-60-06b8bda54513>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023':'26-08-2023', 'C5':'C5']
#                  C5
# 2023-08-26  0.36156

# %%
df.loc['25-08-2023':'25-08-2023', 'C6':'C6']
# Out:
# <ipython-input-61-9c2b294ee558>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023':'25-08-2023', 'C6':'C6']
#                   C6
# 2023-08-25  0.868264

# %%
# I LOCK

# %%
df.iloc[:,:]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.iloc[:,:2]
# Out:
#                   C1        C2
# 2023-08-25  0.552904  0.686307
# 2023-08-26  0.005602  0.961392
# 2023-08-27  0.295969  0.413688
# 2023-08-28  0.730438  0.125866
# 2023-08-29  0.436829  0.859897
# 2023-08-30  0.887732  0.075779
# 2023-08-31  0.142417  0.220939

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.loc['2023-08-27':, :] #this takes all the columns
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.loc[:'2023-08-27', :] # giving 27 as end date
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559

# %%
df.loc[:,'C3':]
# Out:
#                   C3        C4        C5        C6        C7
# 2023-08-25  0.910754  0.655889  0.359469  0.868264  0.920107
# 2023-08-26  0.499078  0.240960  0.361560  0.717672  0.165532
# 2023-08-27  0.612036  0.458560  0.414341  0.720099  0.338559
# 2023-08-28  0.598776  0.936758  0.807513  0.704970  0.165889
# 2023-08-29  0.417358  0.331925  0.879662  0.887619  0.541833
# 2023-08-30  0.668606  0.049275  0.273594  0.796830  0.775908
# 2023-08-31  0.770245  0.776722  0.467282  0.055477  0.595877

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.iloc[3:, :] # this will start with index 3
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.iloc[:3, :]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559

# %%
df.iloc[:, 2:]
# Out:
#                   C3        C4        C5        C6        C7
# 2023-08-25  0.910754  0.655889  0.359469  0.868264  0.920107
# 2023-08-26  0.499078  0.240960  0.361560  0.717672  0.165532
# 2023-08-27  0.612036  0.458560  0.414341  0.720099  0.338559
# 2023-08-28  0.598776  0.936758  0.807513  0.704970  0.165889
# 2023-08-29  0.417358  0.331925  0.879662  0.887619  0.541833
# 2023-08-30  0.668606  0.049275  0.273594  0.796830  0.775908
# 2023-08-31  0.770245  0.776722  0.467282  0.055477  0.595877

# %%
df.iloc[:,:4] #start printing from colum 0 to 3
# Out:
#                   C1        C2        C3        C4
# 2023-08-25  0.552904  0.686307  0.910754  0.655889
# 2023-08-26  0.005602  0.961392  0.499078  0.240960
# 2023-08-27  0.295969  0.413688  0.612036  0.458560
# 2023-08-28  0.730438  0.125866  0.598776  0.936758
# 2023-08-29  0.436829  0.859897  0.417358  0.331925
# 2023-08-30  0.887732  0.075779  0.668606  0.049275
# 2023-08-31  0.142417  0.220939  0.770245  0.776722

# %%
df.iloc[3:, :]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.iloc[:3, :] # before , row after , column
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559

# %%
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.552904  0.686307  0.910754  0.655889  0.359469  0.868264
# 2023-08-26  0.005602  0.961392  0.499078  0.240960  0.361560  0.717672
# 2023-08-27  0.295969  0.413688  0.612036  0.458560  0.414341  0.720099
# 2023-08-28  0.730438  0.125866  0.598776  0.936758  0.807513  0.704970
# 2023-08-29  0.436829  0.859897  0.417358  0.331925  0.879662  0.887619
# 2023-08-30  0.887732  0.075779  0.668606  0.049275  0.273594  0.796830
# 2023-08-31  0.142417  0.220939  0.770245  0.776722  0.467282  0.055477
#
#                   C7
# 2023-08-25  0.920107
# 2023-08-26  0.165532
# 2023-08-27  0.338559
# 2023-08-28  0.165889
# 2023-08-29  0.541833
# 2023-08-30  0.775908
# 2023-08-31  0.595877

# %%
df.iloc[6:,0:1]
# Out:
#                   C1
# 2023-08-31  0.142417

# %%
path = '/content/Churn_Modelling (1).csv'
df_churn_mod = pd.read_csv(path)
df_churn_mod
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod.iloc[100:101, 1:2]
# Out:
#      CustomerId
# 100    15808582

# %%
df_churn_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df_churn_mod.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df_churn_mod.describe(include = 'all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
df_churn_mod.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df_churn_mod.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churn_mod.cummin
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.cummin of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
df_churn_mod.shape
# Out:
# (10000, 14)

# %%
df_churn_mod.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_churn_mod.count()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname            10000
# CreditScore        10000
# Geography          10000
# Gender             10000
# Age                10000
# Tenure             10000
# Balance            10000
# NumOfProducts      10000
# HasCrCard          10000
# IsActiveMember     10000
# EstimatedSalary    10000
# Exited             10000
# dtype: int64

# %%
df_churn_mod.max()
# Out:
# RowNumber              10000
# CustomerId          15815690
# Surname               Zuyeva
# CreditScore              850
# Geography              Spain
# Gender                  Male
# Age                       92
# Tenure                    10
# Balance            250898.09
# NumOfProducts              4
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    199992.48
# Exited                     1
# dtype: object

# %%
df_churn_mod.min()
# Out:
# RowNumber                 1
# CustomerId         15565701
# Surname               Abazu
# CreditScore             350
# Geography            France
# Gender               Female
# Age                      18
# Tenure                    0
# Balance                 0.0
# NumOfProducts             1
# HasCrCard                 0
# IsActiveMember            0
# EstimatedSalary       11.58
# Exited                    0
# dtype: object

# %%
df_churn_mod.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_churn_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df_churn_mod.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df_churn_mod.CreditScore
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
df_churn_mod['CreditScore']
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
df_churn_mod.CreditScore, df_churn_mod.Geography
# Out:
# (0       619
#  1       608
#  2       502
#  3       699
#  4       850
#         ...
#  9995    771
#  9996    516
#  9997    709
#  9998    772
#  9999    792
#  Name: CreditScore, Length: 10000, dtype: int64,
#  0        France
#  1         Spain
#  2        France
#  3        France
#  4         Spain
#           ...
#  9995     France
#  9996     France
#  9997     France
#  9998    Germany
#  9999     France
#  Name: Geography, Length: 10000, dtype: object)

# %%
df_churn_mod[['CreditScore', 'Geography']]
# Out:
#       CreditScore Geography
# 0             619    France
# 1             608     Spain
# 2             502    France
# 3             699    France
# 4             850     Spain
# ...           ...       ...
# 9995          771    France
# 9996          516    France
# 9997          709    France
# 9998          772   Germany
# 9999          792    France
#
# [10000 rows x 2 columns]

# %%
df_churn_mod[['Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard']]
# Out:
#       Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard
# 0     Female   42       2       0.00              1          1
# 1     Female   41       1   83807.86              1          0
# 2     Female   42       8  159660.80              3          1
# 3     Female   39       1       0.00              2          0
# 4     Female   43       2  125510.82              1          1
# ...      ...  ...     ...        ...            ...        ...
# 9995    Male   39       5       0.00              2          1
# 9996    Male   35      10   57369.61              1          1
# 9997  Female   36       7       0.00              1          0
# 9998    Male   42       3   75075.31              2          1
# 9999  Female   28       4  130142.79              1          1
#
# [10000 rows x 6 columns]

# %% [markdown]
# #**Data selection based on Condition**

# %%
df_churn_mod[(df_churn_mod.Gender == 'Male') & (df_churn_mod.Age > 45)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender  Age  \
# 6             7    15592531   Bartlett          822    France   Male   50
# 16           17    15737452      Romeo          653   Germany   Male   58
# 23           24    15725737     Mosman          669    France   Male   46
# 59           60    15804771  Velazquez          614    France   Male   51
# 63           64    15751208    Pirozzi          684     Spain   Male   56
# ...         ...         ...        ...          ...       ...    ...  ...
# 9951       9952    15763874         Ho          635     Spain   Male   46
# 9953       9954    15655952      Burke          550    France   Male   47
# 9967       9968    15603794   Pugliesi          623    France   Male   48
# 9975       9976    15666295      Smith          610   Germany   Male   50
# 9986       9987    15581736   Bartlett          673   Germany   Male   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod[(df_churn_mod.CreditScore > 650) & (df_churn_mod.Age >45)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 6             7    15592531   Bartlett          822    France    Male   50
# 16           17    15737452      Romeo          653   Germany    Male   58
# 23           24    15725737     Mosman          669    France    Male   46
# 43           44    15755196     Lavine          834    France  Female   49
# 44           45    15684171    Bianchi          660     Spain  Female   61
# ...         ...         ...        ...          ...       ...     ...  ...
# 9948       9949    15735078  Onwughara          724   Germany  Female   53
# 9949       9950    15798615        Wan          850    France  Female   47
# 9979       9980    15692664     Diribe          677    France  Female   58
# 9982       9983    15768163    Griffin          655   Germany  Female   46
# 9986       9987    15581736   Bartlett          673   Germany    Male   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod[(df_churn_mod.CreditScore > 650) & (df_churn_mod.Age >45)& (df_churn_mod.Geography == 'France')]
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 6             7    15592531  Bartlett          822    France    Male   50
# 23           24    15725737    Mosman          669    France    Male   46
# 43           44    15755196    Lavine          834    France  Female   49
# 76           77    15614049        Hu          664    France    Male   55
# 162         163    15630910    Treacy          800    France  Female   49
# ...         ...         ...       ...          ...       ...     ...  ...
# 9909       9910    15773338  Endrizzi          739    France    Male   58
# 9920       9921    15673020     Smith          678    France  Female   49
# 9933       9934    15765375   Butusov          797    France  Female   46
# 9949       9950    15798615       Wan          850    France  Female   47
# 9979       9980    15692664    Diribe          677    France  Female   58
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df_churn_mod[(df_churn_mod.CreditScore > 650) | (df_churn_mod.Age >45)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# 6             7    15592531   Bartlett          822    France    Male   50
# 9            10    15592389         H?          684    France    Male   27
# 16           17    15737452      Romeo          653   Germany    Male   58
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...
