# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('homeprices.csv')
df

# %%
plt.scatter(df.area, df.price,color='red',marker='+')
plt.plot(x_values, y_values, label='Linear Regression', color='Black')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Housing Price Analysis')

# %%
# # Scatter plot
# plt.scatter(df['area'], df['price'], color='red', marker='+', label='Data Points')

# # linear regression line
# coefficients = np.polyfit(df['area'], df['price'], 1)
# x_values = np.linspace(min(df['area']), max(df['area']), 100)
# y_values = coefficients[0] * x_values + coefficients[1]
# plt.plot(x_values, y_values, label='Linear Regression', color='Black')

# plt.xlabel('Area')
# plt.ylabel('Price')
# plt.title('Housing Price Analysis')
# plt.legend()
# plt.show()

# %%
df.area, df.price

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

# %%
new_df = df.drop('price',axis='columns')
new_df

# %%
price = df.price
price

# %%
reg.fit(new_df,price)

# %%
reg.predict([[3300]]) # 628715.75342466

# %%
reg.predict([[4000]])

# %%
'''
y = mx + c
y = dependent variable
m = slope
x = independent variable
c = intercept
'''

# %%
reg.coef_ # 135.78767123

# %%
reg.intercept_ # 180616.43835616432

# %%
(135.78767123*3300)+180616.43835616432 # [628715.75342466]
