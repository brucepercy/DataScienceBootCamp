# %%
temp_str = "Hello World"
# string slicing [start:stop:step]

print(temp_str[::2]) # skips two strings

# %%
temp_str = "Hello World"
dir(temp_str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
temp_str = "hello World"
# The capitalize funtion capitalizes the first letter (upper case)
print(temp_str.capitalize())
# Out:
# Hello world

# %%
temp_str = "HeLLO World"
# Returns a string where al characters are lowercase
print(temp_str.casefold())
# Out:
# hello world

# %%
temp_str = " Hello World "
# It takes two arguments : Whats the length we want and whats the string which needs to be filled
# Increases length of string by adding whatever character is mentioned if not by default fills by space
print(temp_str.center(21,"*"))
# Out:
# **** Hello World ****

# %%
temp_str = " Hello World, How is it going, world, Is everything is fine? "
# Returns how many times the substring appears in the given range by default picks full string
# Count functions is case sensitiv
print(temp_str)
print(temp_str.count("world"))
print(temp_str.count("World")) # UPPERCASE LETTER


print()
temp_str1 = " Hello World, How is it going, world, Is everything fine? ".casefold()
print(temp_str1.count("world"))

print()
# How to give range
# count (value, start, end)
# Start and end are optional if not given takes full string
temp_str_2 = "Hello World, How is it going? hello all good hello"
print(temp_str_2[2:5])
print(temp_str_2.count(" Hello ",2))
# Out:
#  Hello World, How is it going, world, Is everything is fine?
# 1
# 1
#
# 2
#
# llo
# 0

# %%
# Funtion that returns True or false on the basis of suffix passed
temp_str = "HeLLo WorLD how is it going? Hello all good!"
# endswith(value,start,end) -1
print (temp_str.endswith("Lo",0,5)) #case sensitive
print (temp_str.endswith("LO",0,5)) #case sensitive O is uppercase so it will return false
print (temp_str.endswith("good",0,len(temp_str)-1))
print (len(temp_str))
# Out:
# True
# False
# True
# 44

# %%
# Returns lowest index of the substring if found else returns -1
temp_str = "HeLLo WorLD how is it going? Hello all good! how are you?!"
print(temp_str.find("howhfjakdnjsn"))
print(temp_str.find("how"))
# Out:
# -1
# 12

# %%
temp_str = "Hello my name is {fname}, I am a {position}"
print(temp_str)
print()

print(temp_str.format(fname="Bruce", position = "Date Scientist"))
print()

temp_str1 = "Hello my name is {1}, I am a {0}" # 0 and 1 refers to the index
print(temp_str1.format("Data Scientist", "Bruce")) # replaces the value for the index
# Out:
# Hello my name is {fname}, I am a {position}
#
# Hello my name is Bruce, I am a Date Scientist
#
# Hello my name is Bruce, I am a Data Scientist

# %% [markdown]
# # Funtions jumped
#  1 format map
#  2 expand tabs

# %%
# Replica of find funtion
temp_str = "HeLLo WorLD how is it going? Hello all good! how are you?!"
temp_str.index("how")
#temp_str.index("How")  # case sensitive
# Out:
# 12

# %%
# Returns True if only numbers and alphabets are present else returns false
temp_str = "Hello World How are you?"
temp_str1 = "HelloWorldHowareyou123"
print(temp_str.isalnum()) # alpha Numeric
print(temp_str1.isalnum())
print(temp_str[0:5].isalnum())
# Out:
# False
# True
# True

# %%
# Returns True if only alphabets are present else returns false
temp_str = "HelloWorldHowareyou"
temp_str1 = "HelloWorldHowareyou123"
print(temp_str.isalpha()) # alpha only
print(temp_str.isalpha())
print(temp_str[0:5].isalpha())
# Out:
# True
# True
# True

# %%
# Returns true if only numbers between 0-9 else return false
temp_str = "Hello World"
print(temp_str.isdecimal())
temp_str1 = "45454535"
print(temp_str1.isdecimal())
temp_str2 = "  45454535"
print(temp_str2.isdecimal())
temp_str3 = "\u0030"
print(temp_str3.isdecimal())
# Out:
# False
# True
# False
# True

# %%
#  Returns true if only its a digit else return false
temp_str = "Hello World"
print(temp_str.isdigit())
temp_str1 = "45454535"
print(temp_str1.isdigit())
temp_unicode = "\u0030"
print(temp_unicode.isdigit())
# Out:
# False
# True
# True

# %%
# Reurns do not work with subscript and digits works with it
temp_str = "\u00B2"
print("Km\\u00B2")
print(temp_str.isdecimal())
print(temp_str.isdigit())
# Out:
# Km\u00B2
# False
# True

# %%
# returns true if the word is a keyword in oythin else retrun false
temp_str = "Hello World"
print(temp_str.isidentifier())
temp_str2 = "if"
print(temp_str2.isidentifier())
# Out:
# False
# True

# %%
temp_str = "Hello World"
temp_str2 = "Hello world1223454545454!!@@@@"
print(temp_str.islower())
print(temp_str2.islower())
# Out:
# False
# False

# %%
# Returns true if there is white spaces
temp_str = "Hello World"
print(temp_str.isspace())
temp_str1 = "    "
print(temp_str1.isspace())
# Out:
# False
# True

# %%
# Returns if the fisrt letter is upper case
temp_str = "Hello World" # The first character of each work here is the capital letter
print(temp_str.istitle())
temp_str1 = "Hello WOrld"
print(temp_str1.istitle())
# Out:
# True
# False

# %%
# Returns if the all the letters are upper case
temp_str = "Hello World"
print(temp_str.isupper())
temp_str1 = "HELLO WORLD 45433%%%%3"
print(temp_str1.isupper())
# Out:
# False
# True

# %%
# ITERABLES ARE LIST TUPLES
list_temp = ["11111", "World", "How", "Are", "You"]
print("#".join(list_temp))
# Out:
# 11111#World#How#Are#You

# %%
# lower
temp_str = "Hello World"
print(temp_str.lower())
string_german = "ß"
print(string_german.lower())
print(string_german.casefold())
# Out:
# hello world
# ß
# ss

# %%
# Removes the white spaces on the left hand side of the string
temp_str = "                     Hello World"
print(temp_str.lstrip())
# Out:
# Hello World

# %%
# Removes the white spaces on the right hand side of the string
temp_str = "Hello World           "
print(temp_str.rstrip())
# Out:
# Hello World

# %%
# finds the word and partitions that
temp_str = " I could eat apples all day"
temp_str1 = " I could eat you all day"
print(temp_str.partition("apples"))
print(temp_str1.partition("apples"))
# Out:
# (' I could eat ', 'apples', ' all day')
# (' I could eat you all day', '', '')

# %%
# Replaces the second word we define to the first word.
temp_str = " I could eat apples all day, thats all i can say and thats all i need"
print(temp_str.replace('all','not').replace('day', 'all day'))
# Out:
#  I could eat apples not all day, thats not i can say and thats not i need

# %%
# Splits the string in the given parameter
temp_str = "I could eat apples all day, thats all i can say"
print(temp_str.split())
print()
print(temp_str.split(","))
print()
print(temp_str.split("eat"))
# Out:
# ['I', 'could', 'eat', 'apples', 'all', 'day,', 'thats', 'all', 'i', 'can', 'say']
#
# ['I could eat apples all day', ' thats all i can say']
#
# ['I could ', ' apples all day, thats all i can say']

# %%
temp_str = "I could eat apples all day, thats all i can say"
print(temp_str.startswith("I"))
print(temp_str.startswith("eat",8))
# Out:
# True
# True

# %%
# It just strips both sides
temp_str = "       Hello.      "
temp_str.strip()
# Out:
# 'Hello.'

# %%
# swaps the case of the string
temp_str = "I could eat Apples all day, thats all i can say"
temp_str.swapcase()
# Out:
# 'i COULD EAT aPPLES ALL DAY, THATS ALL I CAN SAY'

# %%
# makes all the first letter of each string uppercase
temp_str = "I could eat Apples all day, thats all i can say"
temp_str.title()
# Out:
# 'I Could Eat Apples All Day, Thats All I Can Say'

# %%
# Removes the Duplicate value
temp_str = {83:60, 83:30, 83:78}
print(temp_str)
print()
temp_str1 = {"Brand": "Ford", "Model": "Mustang", "Year":1969, "Year":1970}
print(temp_str1)
# Out:
# {83: 78}
#
# {'brand': 'Ford', 'model': 'Mustang', 'Year': 1970}

# %%
thisdict = dict(Brand = "BMW", Year = 2023, Country = "Germany")
print(thisdict)
# Out:
# {'Brand': 'BMW', 'Year': 2023, 'Country': 'Germany'}

# %%
# ASSCI code value of s is 83 defaultly we replace it with 80 here which is P
temp_dict = {83:80, 72:77} # here 83 in assci is H and 80 is something
temp_str = "Hello Sam ! SHHHHHHH"
temp_str.translate(temp_dict)
# Out:
# 'Mello Pam ! PMMMMMMM'

# %%
temp_str = "I could eat Apples all day, thats all i can say"
temp_str.upper()
# Out:
# 'I COULD EAT APPLES ALL DAY, THATS ALL I CAN SAY'

# %%
# ADDS 0 in the beginning to fill to the parameter
temp_str = "I could eat Apples all day, thats all i can say"
print(len(temp_str))
print(temp_str.zfill(10))
print(temp_str.zfill(60))
# Out:
# 47
# I could eat Apples all day, thats all i can say
# 0000000000000I could eat Apples all day, thats all i can say
