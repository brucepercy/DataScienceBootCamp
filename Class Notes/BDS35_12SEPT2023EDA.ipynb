# %%
x= 1
y=2

if x < y:
  print(x, 'is smaller than', y)
elif x > y:
  print(x, "is greater than", y)
else:
  print(x, "is equal to", y)

#lambda Equivalant
result = lambda x,y : f"{x} is smaller than {y}"\
if x < y else (f"{x} is greater than {y}" if x>y\
               else f"{x} is equal to {y}")

# %%
percentage = float(input("Enter marks:" ))

if (percentage >= 78):
  print("Pass with first class disctinction")
elif (percentage >= 60):
  print("Pass with first class")
elif(percentage >=  40):
  print("Pass with Second class")
elif (percentage >= 35):
  print("Pass with third class")
else:
  print("Better luck next time")

#Lambda Equivalent
result = lambda percentage :
f"{percentage} is greater than {78}, Pass with first class distinction" if percentage >= 78 else (\
f"{percentage} is greater than {60}, pass with first class" if percentage >=60 else              (\
f"{percentage} is greater than {40}, pass with second class" if percentage >= 40 else            (\
f"{percentage} is greater than {35}, pass with third class" if percentage >=  35 else            (\
f"{percentage} is lower than {35}, better luck next time"
                                                                                                  )
)
)
)
# Out:
# Enter marks:54
# Pass with Second class

# %%
def func_sum (a,b):
  return a + b

# %%
def func_sum(a,b,c,d,e,f):
  return a + b+ c + d + e + f

# %%
def func_sum (*args)

# %%
def func_sum(a, b, c, d, a1, b1, c1, d1):
  return a + b + c + d + a1 + b1 + c1 + d1

# %%
def func_sum(*args): # *args (Non-Keyword Arguments)
  return args

# %%
def func_sum(*anurag): # *args (Non-Keyword Arguments)
  return anurag

# %%
def func_sum(*args): # *args (Non-Keyword Arguments)
  return args

# %%
func_sum(12,23,34,45,56,67,78,89,90,101)
# Out:
# (12, 23, 34, 45, 56, 67, 78, 89, 90, 101)

# %%
def profit_daily(*BruceGTheManTho):
  return sum(BruceGTheManTho)

# %%
profit_daily(10,20,30,40,30,20,10, 40)
# Out:
# 200

# %%
profit_list = []

while True:
  prof_input = input("Enter your profit for today (or 'x' to calculate total): ")

  if prof_input.lower() == 'x':
    break

  try:
    prof_input = float(prof_input)
    profit_list.append(prof_input)
  except ValueError:
    print("Invalid input. Please enter a valid number or 'x' to calculate total.")

def profit_daily(*BruceG):
  return sum(BruceG)

total_profit = profit_daily(profit_list)
print(f"Total profit: {profit_daily}")

# %%
profit_list = []
while True:
  prof_input = input("Enter your profit for today (or 'x' to calculate total): ")

  if prof_input.lower() == 'x':
    break
  try:
    prof_input = float(prof_input)
    profit_list.append(prof_input)
  except ValueError:
    print("Invalid input. Please enter a valid number or 'x' to calculate total.")
def profit_daily(*args):
  return sum(args)
total_profit = profit_daily(*profit_list)
print(f"Total profit: {total_profit}")

# %%
def func_sum(*args): # *args (Non-Keyword Arguments)
  return args

# %%
func_sum(12,23,34,45,56,67,78,89,90,101)
# Out:
# (12, 23, 34, 45, 56, 67, 78, 89, 90, 101)

# %%
func_sum([12,23,34],(45,56,67),78,89,90,101)
# Out:
# ([12, 23, 34], (45, 56, 67), 78, 89, 90, 101)

# %%
func_sum({12,23,34,45,56},67,78,89,90,101)
# Out:
# ({12, 23, 34, 45, 56}, 67, 78, 89, 90, 101)

# %%
func_sum({'a':12,'b':23,'c':34,'d':45,'e':56},67,78,89,90,101)
# Out:
# ({'a': 12, 'b': 23, 'c': 34, 'd': 45, 'e': 56}, 67, 78, 89, 90, 101)

# %%
# FIRST ARGUMENT * ARGS
# five more vairables
# and then takes values for it

def function_fivemore(*args, a,b,c,d,e):
  return (sum(args, a,b,c,d,e))
result = function_fivemore(1, 2, 3, 4, 5, 6, 7)
print(result)

# %%
# def func_sum(*args):# its a key word argument
#   return args
#   will give error

def func_sum(**kwargs):# its a key word argument
 return kwargs

# %%
func_sum(fname= 'Bruce', mname = 'Percy', lname ='Jebaraj', DOB = 1999, Gender = 'M')
# Out:
# {'fname': 'Bruce',
#  'mname': 'Percy',
#  'lname': 'Jebaraj',
#  'DOB': 1999,
#  'Gender': 'M'}

# %%
def func_sum(fname, mname, lname, DOB,Gender,*args, **kwargs):# its a key word argument
  return args, kwargs

# %%
def func_sum(*args, **kwargs):# its a key word argument
  return args, kwargs
# it should be always in this order first args then kwargs

# %%
def func_sum(**kwargs,*args):# its a key word argument
  return args, kwargs

# %%
#func_sum('Bruce', 'Percy', 'Jebaraj',1999, 'M', "Comp Science")
func_sum(12,23,34,"BOSE", fname= 'Bruce', mname = 'Percy', lname ='Jebaraj', DOB = 1999, Gender = 'M',  grad="Comp Science")
# Out:
# ((12, 23, 34, 'BOSE'),
#  {'fname': 'Bruce',
#   'mname': 'Percy',
#   'lname': 'Jebaraj',
#   'DOB': 1999,
#   'Gender': 'M',
#   'grad': 'Comp Science'})

# %%
# firs tvalue should be kwargs
# second values args
# normal

# write three different combinations

# %%
def function1(**kwargs, *args, normal):
  return kwargs, args, normal

# %%
functions1(12,23,34,"BOSE", fname= 'Bruce', mname = 'Percy', lname ='Jebaraj', DOB = 1999, Gender = 'M',  grad="Comp Science")

# %%
def function2(*args, **kwargs, normal):
  return args, kwargs, normal

# %%
functions2(12,23,34,"BOSE", fname= 'Bruce', mname = 'Percy', lname ='Jebaraj', DOB = 1999, Gender = 'M',  grad="Comp Science")

# %%
def function3(normal, **kwargs, *args):
  return normal, kwargs, args

# %%
functions3(12,23,34,"BOSE", fname= 'Bruce', mname = 'Percy', lname ='Jebaraj', DOB = 1999, Gender = 'M',  grad="Comp Science")

# %%
def function4(normal, *args, **kwargs):
  return normal, args, kwargs

# %%
functions4(12,23,34,"BOSE", fname= 'Bruce', mname = 'Percy', lname ='Jebaraj', DOB = 1999, Gender = 'M',  grad="Comp Science")
