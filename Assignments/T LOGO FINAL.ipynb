# %%
from turtle import *
import time

# Setting up the speed of the turtle cursor
speed(1)

# Setting up the screen with a background image
image_path = r"C:\Users\bruce\Downloads\x43mybmzvajeiuc6dddcsep2qx6jc3sachvcdoaizecfr3dnitcq_3_0.png"
screen = Screen()
screen.bgpic(image_path)

# Set the starting positions and the height width of the first rectangle
start_x, start_y = -160, 110
rectangle_width = 340
rectangle_height = 60

# Move to the starting position for the first rectangle
up()
goto(start_x, start_y)
down()

# Filling it with a color
fillcolor('black')
begin_fill()
for _ in range(2):
    forward(rectangle_width)
    left(90)
    forward(rectangle_height)
    left(90)
end_fill()
time.sleep(0.2)

# Sets the starting position of e the second rectangle and the height and the width
start_x, start_y = -15, -190
rectangle_width = 50
rectangle_height = 300

# Moves the start position fo the second rectangle of the letter T
up()
goto(start_x, start_y)
down()

# Filling it with a color
fillcolor('black')
begin_fill()
for _ in range(2):
    forward(rectangle_width)
    left(90)
    forward(rectangle_height)
    left(90)
end_fill()
time.sleep(0.2)

# Code to hide the turtle cursor in the end after the drawing
hideturtle()

# The end
done()
